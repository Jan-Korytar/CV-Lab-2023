# %%
import numpy as np
from matplotlib import pyplot as plt
from torchvision import models
from torchsummary import summary
from model import UNet

# %%
model = UNet(3, 64, 3, 1)
summary(model, (3, 512, 512))
# Out:
# ...
# Layer (type:depth-idx)                   Output Shape              Param #
# ...
# ├─encoder_block: 1-1                     [-1, 64, 512, 512]        --
# |    └─conv_block: 2-1                   [-1, 64, 512, 512]        --
# |    |    └─Conv2d: 3-1                  [-1, 64, 512, 512]        1,792
# |    |    └─BatchNorm2d: 3-2             [-1, 64, 512, 512]        128
# |    |    └─ReLU: 3-3                    [-1, 64, 512, 512]        --
# |    |    └─Conv2d: 3-4                  [-1, 64, 512, 512]        36,928
# |    |    └─BatchNorm2d: 3-5             [-1, 64, 512, 512]        128
# |    |    └─ReLU: 3-6                    [-1, 64, 512, 512]        --
# |    └─MaxPool2d: 2-2                    [-1, 64, 256, 256]        --
# ├─encoder_block: 1-2                     [-1, 128, 256, 256]       --
# |    └─conv_block: 2-3                   [-1, 128, 256, 256]       --
# |    |    └─Conv2d: 3-7                  [-1, 128, 256, 256]       73,856
# ...

# %%
losses = [0.20263411211115973, 0.04804019683173725, 0.04347977627600942, 0.029305878760559217, 0.02700548858514854, 0.03490102916423764, 0.02723967842757702, 0.016077519926641668, 0.014277057988303048, 0.015648079237767627, 0.012152519808816058, 0.016091397697372094, 0.009769294277897902, 0.011795371571289641, 0.024092228883611306, 0.01414027504090752, 0.01878474506416491, 0.01037450720156942, 0.006505627584244523, 0.0055247511980789045, 0.008290950641302126, 0.00866812577338091, 0.008075298741459846, 0.011052786771740233, 0.006379078940621444, 0.005637160302805049, 0.006378130987286568, 0.005750904491703425, 0.005366112438163587, 0.016573503813041107, 0.014562161107148443, 0.021302135395152227, 0.01761977979913354, 0.009500146377831697, 0.014501392708293028, 0.01353177401636328, 0.009882071920271431, 0.009865221833544118, 0.010091054386326246, 0.007668786050219621, 0.00564205925911665, 0.008174737715827567, 0.006397250141682369, 0.005234571606186884, 0.00717130017333797, 0.0053724633263690135, 0.0047952645857419285, 0.006779056574617114, 0.005046244045453412, 0.008257759967818856]
plt.plot(losses)
plt.title('MSEloss value on training set')
plt.ylabel('MSEloss')
plt.xlabel('epoch')
plt.show()
